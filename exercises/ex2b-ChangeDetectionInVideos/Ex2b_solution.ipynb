# %% [markdown]
# This is an example of a file containing the solutions. Everything between the solution tags will be integrated into the course web-page as according to the cronjob GitHub Action which checks the release dates from schedules.csv and builds a payload to push to the puppet repository.

# %%
#< START_SOLUTION 1>
import numpy 
print(np.zeros(1337,1337).shape) #example solution
#< END_SOLUTION 1>

# %%
#< START_SOLUTION 2>
print(np.zeros(2337,2337).shape) #example solution
#< END_SOLUTION 2>

# %%
#< START_SOLUTION 3>
print(np.zeros(3337,3337).shape) #example solution
#< END_SOLUTION 3>
